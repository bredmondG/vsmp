# %%
import os

# %%
def slice_video(filename, start_range = 0):
    #cuts file into 20 equal sections
    stop_range = start_range + 20
    movie_name = filename.split(".")[0]
    file_type = "." + filename.split(".")[1]
    os.mkdir(movie_name)
    s = os.popen('ffprobe -v error -select_streams v:0 -show_entries stream=duration -of default=noprint_wrappers=1:nokey=1 {}'.format(filename))
    seconds = float(s.read().split()[0])
    duration = seconds/20
    t = 0
    for i in range(start_range, stop_range):
        print(t, t + duration)
        command = 'ffmpeg -i {} -ss {} -t {} -c copy {}/{}_section{}{}'.format(filename, t, duration, movie_name, movie_name, i, file_type)
        output = os.popen(command)
        print(output.read())
        t+= duration

# %%
def print_video(filename, start_range = 0):
    #cuts file into 20 equal sections
    stop_range = start_range + 20
    movie_name = filename.split(".")[0]
    file_type = "." + filename.split(".")[1]
    os.mkdir(movie_name)
    print(stop_range)
    print(movie_name)
    print(file_type)
    # s = os.popen('ffprobe -v error -select_streams v:0 -show_entries stream=duration -of default=noprint_wrappers=1:nokey=1 {}'.format(filename))
    # seconds = float(s.read().split()[0])
    # duration = seconds/20
    # t = 0
    # for i in range(start_range, stop_range):
    #     print(t, t + duration)
    #     command = 'ffmpeg -i {} -ss {} -t {} -c copy {}/{}_section{}{}'.format(filename, t, duration, movie_name, movie_name, i, file_type)
    #     output = os.popen(command)
    #     print(output.read())
    #     t+= duration

# %%
print_video("Steamboat_Willie.mp4")
# Out:
# 20
# Steamboat_Willie
# .mp4

# %%
slice_video("metropolis.mp4")
# Out:
# 0 446.70459165
#
# 446.70459165 893.4091833
# ffmpeg version 4.1.4 Copyright (c) 2000-2019 the FFmpeg developers
#   built with Apple LLVM version 10.0.1 (clang-1001.0.46.4)
#   configuration: --prefix=/usr/local/Cellar/ffmpeg/4.1.4_2 --enable-shared --enable-pthreads --enable-version3 --enable-avresample --cc=clang --host-cflags='-I/Library/Java/JavaVirtualMachines/adoptopenjdk-12.0.1.jdk/Contents/Home/include -I/Library/Java/JavaVirtualMachines/adoptopenjdk-12.0.1.jdk/Contents/Home/include/darwin' --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libbluray --enable-libmp3lame --enable-libopus --enable-librubberband --enable-libsnappy --enable-libtesseract --enable-libtheora --enable-libvorbis --enable-libvpx --enable-libx264 --enable-libx265 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-librtmp --enable-libspeex --enable-videotoolbox --disable-libjack --disable-indev=jack --enable-libaom --enable-libsoxr
#   libavutil      56. 22.100 / 56. 22.100
#   libavcodec     58. 35.100 / 58. 35.100
#   libavformat    58. 20.100 / 58. 20.100
#   libavdevice    58.  5.100 / 58.  5.100
#   libavfilter     7. 40.101 /  7. 40.101
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  3.100 /  5.  3.100
#   libswresample   3.  3.100 /  3.  3.100
#   libpostproc    55.  3.100 / 55.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'metropolis.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.45.100
#   Duration: 02:28:54.25, start: 0.000000, bitrate: 1622 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1920x1080 [SAR 1:1 DAR 16:9], 1488 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 47.95 tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
# Output #0, mp4, to 'metropolis/metropolis_section0.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.20.100
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 1488 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 24k tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# frame=10584 fps=0.0 q=-1.0 Lsize=   48595kB time=00:07:26.69 bitrate= 891.2kbits/s speed=6.41e+03x
# video:41302kB audio:6980kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.650461%
# ffmpeg version 4.1.4 Copyright (c) 2000-2019 the FFmpeg developers
#   built with Apple LLVM version 10.0.1 (clang-1001.0.46.4)
#   configuration: --prefix=/usr/local/Cellar/ffmpeg/4.1.4_2 --enable-shared --enable-pthreads --enable-version3 --enable-avresample --cc=clang --host-cflags='-I/Library/Java/JavaVirtualMachines/adoptopenjdk-12.0.1.jdk/Contents/Home/include -I/Library/Java/JavaVirtualMachines/adoptopenjdk-12.0.1.jdk/Contents/Home/include/darwin' --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libbluray --enable-libmp3lame --enable-libopus --enable-librubberband --enable-libsnappy --enable-libtesseract --enable-libtheora --enable-libvorbis --enable-libvpx --enable-libx264 --enable-libx265 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-librtmp --enable-libspeex --enable-videotoolbox --disable-libjack --disable-indev=jack --enable-libaom --enable-libsoxr
#   libavutil      56. 22.100 / 56. 22.100
#   libavcodec     58. 35.100 / 58. 35.100
#   libavformat    58. 20.100 / 58. 20.100
#   libavdevice    58.  5.100 / 58.  5.100
#   libavfilter     7. 40.101 /  7. 40.101
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  3.100 /  5.  3.100
#   libswresample   3.  3.100 /  3.  3.100
#   libpostproc    55.  3.100 / 55.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'metropolis.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.45.100
#   Duration: 02:28:54.25, start: 0.000000, bitrate: 1622 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1920x1080 [SAR 1:1 DAR 16:9], 1488 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 47.95 tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
# Output #0, mp4, to 'metropolis/metropolis_section1.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.20.100
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 1488 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 24k tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# frame=10686 fps=0.0 q=-1.0 Lsize=  130029kB time=00:07:26.68 bitrate=2384.7kbits/s speed=3.17e+03x
# video:122733kB audio:6980kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.243435%
# ffmpeg version 4.1.4 Copyright (c) 2000-2019 the FFmpeg developers
#   built with Apple LLVM version 10.0.1 (clang-1001.0.46.4)
#   configuration: --prefix=/usr/local/Cellar/ffmpeg/4.1.4_2 --enable-shared --enable-pthreads --enable-version3 --enable-avresample --cc=clang --host-cflags='-I/Library/Java/JavaVirtualMachines/adoptopenjdk-12.0.1.jdk/Contents/Home/include -I/Library/Java/JavaVirtualMachines/adoptopenjdk-12.0.1.jdk/Contents/Home/include/darwin' --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libbluray --enable-libmp3lame --enable-libopus --enable-librubberband --enable-libsnappy --enable-libtesseract --enable-libtheora --enable-libvorbis --enable-libvpx --enable-libx264 --enable-libx265 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-librtmp --enable-libspeex --enable-videotoolbox --disable-libjack --disable-indev=jack --enable-libaom --enable-libsoxr
#   libavutil      56. 22.100 / 56. 22.100
#   libavcodec     58. 35.100 / 58. 35.100
#   libavformat    58. 20.100 / 58. 20.100
#   libavdevice    58.  5.100 / 58.  5.100
#   libavfilter     7. 40.101 /  7. 40.101
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  3.100 /  5.  3.100
#   libswresample   3.  3.100 /  3.  3.100
#   libpostproc    55.  3.100 / 55.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'metropolis.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.45.100
#   Duration: 02:28:54.25, start: 0.000000, bitrate: 1622 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1920x1080 [SAR 1:1 DAR 16:9], 1488 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 47.95 tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
# Output #0, mp4, to 'metropolis/metropolis_section2.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.20.100
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 1488 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 24k tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# 893.4091833 1340.1137749499999
# frame=10641 fps=0.0 q=-1.0 Lsize=  124891kB time=00:07:26.68 bitrate=2290.4kbits/s speed=2.36e+03x
# video:117595kB audio:6980kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.253133%
# ffmpeg version 4.1.4 Copyright (c) 2000-2019 the FFmpeg developers
#   built with Apple LLVM version 10.0.1 (clang-1001.0.46.4)
#   configuration: --prefix=/usr/local/Cellar/ffmpeg/4.1.4_2 --enable-shared --enable-pthreads --enable-version3 --enable-avresample --cc=clang --host-cflags='-I/Library/Java/JavaVirtualMachines/adoptopenjdk-12.0.1.jdk/Contents/Home/include -I/Library/Java/JavaVirtualMachines/adoptopenjdk-12.0.1.jdk/Contents/Home/include/darwin' --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libbluray --enable-libmp3lame --enable-libopus --enable-librubberband --enable-libsnappy --enable-libtesseract --enable-libtheora --enable-libvorbis --enable-libvpx --enable-libx264 --enable-libx265 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-librtmp --enable-libspeex --enable-videotoolbox --disable-libjack --disable-indev=jack --enable-libaom --enable-libsoxr
#   libavutil      56. 22.100 / 56. 22.100
#   libavcodec     58. 35.100 / 58. 35.100
#   libavformat    58. 20.100 / 58. 20.100
#   libavdevice    58.  5.100 / 58.  5.100
#   libavfilter     7. 40.101 /  7. 40.101
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  3.100 /  5.  3.100
#   libswresample   3.  3.100 /  3.  3.100
#   libpostproc    55.  3.100 / 55.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'metropolis.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.45.100
#   Duration: 02:28:54.25, start: 0.000000, bitrate: 1622 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1920x1080 [SAR 1:1 DAR 16:9], 1488 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 47.95 tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
# Output #0, mp4, to 'metropolis/metropolis_section3.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.20.100
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 1488 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 24k tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# 1340.1137749499999 1786.8183666
# frame=10600 fps=0.0 q=-1.0 Lsize=   64455kB time=00:07:26.68 bitrate=1182.1kbits/s speed=2.2e+03x
# video:57164kB audio:6980kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.486229%
# ffmpeg version 4.1.4 Copyright (c) 2000-2019 the FFmpeg developers
#   built with Apple LLVM version 10.0.1 (clang-1001.0.46.4)
#   configuration: --prefix=/usr/local/Cellar/ffmpeg/4.1.4_2 --enable-shared --enable-pthreads --enable-version3 --enable-avresample --cc=clang --host-cflags='-I/Library/Java/JavaVirtualMachines/adoptopenjdk-12.0.1.jdk/Contents/Home/include -I/Library/Java/JavaVirtualMachines/adoptopenjdk-12.0.1.jdk/Contents/Home/include/darwin' --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libbluray --enable-libmp3lame --enable-libopus --enable-librubberband --enable-libsnappy --enable-libtesseract --enable-libtheora --enable-libvorbis --enable-libvpx --enable-libx264 --enable-libx265 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-librtmp --enable-libspeex --enable-videotoolbox --disable-libjack --disable-indev=jack --enable-libaom --enable-libsoxr
#   libavutil      56. 22.100 / 56. 22.100
#   libavcodec     58. 35.100 / 58. 35.100
#   libavformat    58. 20.100 / 58. 20.100
#   libavdevice    58.  5.100 / 58.  5.100
#   libavfilter     7. 40.101 /  7. 40.101
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  3.100 /  5.  3.100
#   libswresample   3.  3.100 /  3.  3.100
#   libpostproc    55.  3.100 / 55.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'metropolis.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.45.100
#   Duration: 02:28:54.25, start: 0.000000, bitrate: 1622 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1920x1080 [SAR 1:1 DAR 16:9], 1488 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 47.95 tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
# Output #0, mp4, to 'metropolis/metropolis_section4.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.20.100
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 1488 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 24k tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# 1786.8183666 2233.52295825
# frame=10672 fps=0.0 q=-1.0 Lsize=   79497kB time=00:07:26.68 bitrate=1457.9kbits/s speed=1.88e+03x
# video:72201kB audio:6980kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.400200%
# ffmpeg version 4.1.4 Copyright (c) 2000-2019 the FFmpeg developers
#   built with Apple LLVM version 10.0.1 (clang-1001.0.46.4)
#   configuration: --prefix=/usr/local/Cellar/ffmpeg/4.1.4_2 --enable-shared --enable-pthreads --enable-version3 --enable-avresample --cc=clang --host-cflags='-I/Library/Java/JavaVirtualMachines/adoptopenjdk-12.0.1.jdk/Contents/Home/include -I/Library/Java/JavaVirtualMachines/adoptopenjdk-12.0.1.jdk/Contents/Home/include/darwin' --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libbluray --enable-libmp3lame --enable-libopus --enable-librubberband --enable-libsnappy --enable-libtesseract --enable-libtheora --enable-libvorbis --enable-libvpx --enable-libx264 --enable-libx265 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-librtmp --enable-libspeex --enable-videotoolbox --disable-libjack --disable-indev=jack --enable-libaom --enable-libsoxr
#   libavutil      56. 22.100 / 56. 22.100
#   libavcodec     58. 35.100 / 58. 35.100
#   libavformat    58. 20.100 / 58. 20.100
#   libavdevice    58.  5.100 / 58.  5.100
#   libavfilter     7. 40.101 /  7. 40.101
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  3.100 /  5.  3.100
#   libswresample   3.  3.100 /  3.  3.100
#   libpostproc    55.  3.100 / 55.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'metropolis.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.45.100
#   Duration: 02:28:54.25, start: 0.000000, bitrate: 1622 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1920x1080 [SAR 1:1 DAR 16:9], 1488 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 47.95 tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
# Output #0, mp4, to 'metropolis/metropolis_section5.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.20.100
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 1488 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 24k tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# 2233.52295825 2680.2275499
# frame=10672 fps=0.0 q=-1.0 Lsize=   62729kB time=00:07:26.69 bitrate=1150.4kbits/s speed=1.65e+03x
# video:55433kB audio:6980kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.505459%
# ffmpeg version 4.1.4 Copyright (c) 2000-2019 the FFmpeg developers
#   built with Apple LLVM version 10.0.1 (clang-1001.0.46.4)
#   configuration: --prefix=/usr/local/Cellar/ffmpeg/4.1.4_2 --enable-shared --enable-pthreads --enable-version3 --enable-avresample --cc=clang --host-cflags='-I/Library/Java/JavaVirtualMachines/adoptopenjdk-12.0.1.jdk/Contents/Home/include -I/Library/Java/JavaVirtualMachines/adoptopenjdk-12.0.1.jdk/Contents/Home/include/darwin' --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libbluray --enable-libmp3lame --enable-libopus --enable-librubberband --enable-libsnappy --enable-libtesseract --enable-libtheora --enable-libvorbis --enable-libvpx --enable-libx264 --enable-libx265 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-librtmp --enable-libspeex --enable-videotoolbox --disable-libjack --disable-indev=jack --enable-libaom --enable-libsoxr
#   libavutil      56. 22.100 / 56. 22.100
#   libavcodec     58. 35.100 / 58. 35.100
#   libavformat    58. 20.100 / 58. 20.100
#   libavdevice    58.  5.100 / 58.  5.100
#   libavfilter     7. 40.101 /  7. 40.101
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  3.100 /  5.  3.100
#   libswresample   3.  3.100 /  3.  3.100
#   libpostproc    55.  3.100 / 55.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'metropolis.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.45.100
#   Duration: 02:28:54.25, start: 0.000000, bitrate: 1622 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1920x1080 [SAR 1:1 DAR 16:9], 1488 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 47.95 tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
# Output #0, mp4, to 'metropolis/metropolis_section6.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.20.100
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 1488 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 24k tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# 2680.2275499 3126.9321415500003
# frame=10694 fps=0.0 q=-1.0 Lsize=   71718kB time=00:07:26.68 bitrate=1315.3kbits/s speed=1.41e+03x
# video:64419kB audio:6980kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.446386%
# ffmpeg version 4.1.4 Copyright (c) 2000-2019 the FFmpeg developers
#   built with Apple LLVM version 10.0.1 (clang-1001.0.46.4)
#   configuration: --prefix=/usr/local/Cellar/ffmpeg/4.1.4_2 --enable-shared --enable-pthreads --enable-version3 --enable-avresample --cc=clang --host-cflags='-I/Library/Java/JavaVirtualMachines/adoptopenjdk-12.0.1.jdk/Contents/Home/include -I/Library/Java/JavaVirtualMachines/adoptopenjdk-12.0.1.jdk/Contents/Home/include/darwin' --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libbluray --enable-libmp3lame --enable-libopus --enable-librubberband --enable-libsnappy --enable-libtesseract --enable-libtheora --enable-libvorbis --enable-libvpx --enable-libx264 --enable-libx265 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-librtmp --enable-libspeex --enable-videotoolbox --disable-libjack --disable-indev=jack --enable-libaom --enable-libsoxr
#   libavutil      56. 22.100 / 56. 22.100
#   libavcodec     58. 35.100 / 58. 35.100
#   libavformat    58. 20.100 / 58. 20.100
#   libavdevice    58.  5.100 / 58.  5.100
#   libavfilter     7. 40.101 /  7. 40.101
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  3.100 /  5.  3.100
#   libswresample   3.  3.100 /  3.  3.100
#   libpostproc    55.  3.100 / 55.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'metropolis.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.45.100
#   Duration: 02:28:54.25, start: 0.000000, bitrate: 1622 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1920x1080 [SAR 1:1 DAR 16:9], 1488 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 47.95 tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
# Output #0, mp4, to 'metropolis/metropolis_section7.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.20.100
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 1488 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 24k tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# 3126.9321415500003 3573.6367332000004
# frame=10707 fps=0.0 q=-1.0 Lsize=   61821kB time=00:07:26.68 bitrate=1133.8kbits/s speed=1.31e+03x
# video:54526kB audio:6980kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.513465%
# ffmpeg version 4.1.4 Copyright (c) 2000-2019 the FFmpeg developers
#   built with Apple LLVM version 10.0.1 (clang-1001.0.46.4)
#   configuration: --prefix=/usr/local/Cellar/ffmpeg/4.1.4_2 --enable-shared --enable-pthreads --enable-version3 --enable-avresample --cc=clang --host-cflags='-I/Library/Java/JavaVirtualMachines/adoptopenjdk-12.0.1.jdk/Contents/Home/include -I/Library/Java/JavaVirtualMachines/adoptopenjdk-12.0.1.jdk/Contents/Home/include/darwin' --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libbluray --enable-libmp3lame --enable-libopus --enable-librubberband --enable-libsnappy --enable-libtesseract --enable-libtheora --enable-libvorbis --enable-libvpx --enable-libx264 --enable-libx265 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-librtmp --enable-libspeex --enable-videotoolbox --disable-libjack --disable-indev=jack --enable-libaom --enable-libsoxr
#   libavutil      56. 22.100 / 56. 22.100
#   libavcodec     58. 35.100 / 58. 35.100
#   libavformat    58. 20.100 / 58. 20.100
#   libavdevice    58.  5.100 / 58.  5.100
#   libavfilter     7. 40.101 /  7. 40.101
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  3.100 /  5.  3.100
#   libswresample   3.  3.100 /  3.  3.100
#   libpostproc    55.  3.100 / 55.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'metropolis.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.45.100
#   Duration: 02:28:54.25, start: 0.000000, bitrate: 1622 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1920x1080 [SAR 1:1 DAR 16:9], 1488 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 47.95 tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
# Output #0, mp4, to 'metropolis/metropolis_section8.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.20.100
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 1488 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 24k tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# 3573.6367332000004 4020.3413248500005
# frame=10684 fps=0.0 q=-1.0 Lsize=   42427kB time=00:07:26.68 bitrate= 778.1kbits/s speed=1.22e+03x
# video:35131kB audio:6980kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.752180%
# ffmpeg version 4.1.4 Copyright (c) 2000-2019 the FFmpeg developers
#   built with Apple LLVM version 10.0.1 (clang-1001.0.46.4)
#   configuration: --prefix=/usr/local/Cellar/ffmpeg/4.1.4_2 --enable-shared --enable-pthreads --enable-version3 --enable-avresample --cc=clang --host-cflags='-I/Library/Java/JavaVirtualMachines/adoptopenjdk-12.0.1.jdk/Contents/Home/include -I/Library/Java/JavaVirtualMachines/adoptopenjdk-12.0.1.jdk/Contents/Home/include/darwin' --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libbluray --enable-libmp3lame --enable-libopus --enable-librubberband --enable-libsnappy --enable-libtesseract --enable-libtheora --enable-libvorbis --enable-libvpx --enable-libx264 --enable-libx265 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-librtmp --enable-libspeex --enable-videotoolbox --disable-libjack --disable-indev=jack --enable-libaom --enable-libsoxr
#   libavutil      56. 22.100 / 56. 22.100
#   libavcodec     58. 35.100 / 58. 35.100
#   libavformat    58. 20.100 / 58. 20.100
#   libavdevice    58.  5.100 / 58.  5.100
#   libavfilter     7. 40.101 /  7. 40.101
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  3.100 /  5.  3.100
#   libswresample   3.  3.100 /  3.  3.100
#   libpostproc    55.  3.100 / 55.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'metropolis.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.45.100
#   Duration: 02:28:54.25, start: 0.000000, bitrate: 1622 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1920x1080 [SAR 1:1 DAR 16:9], 1488 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 47.95 tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
# Output #0, mp4, to 'metropolis/metropolis_section9.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.20.100
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 1488 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 24k tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# 4020.3413248500005 4467.0459165
# frame=10689 fps=0.0 q=-1.0 Lsize=   70602kB time=00:07:26.69 bitrate=1294.8kbits/s speed=1.08e+03x
# video:63312kB audio:6980kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.441805%
# ffmpeg version 4.1.4 Copyright (c) 2000-2019 the FFmpeg developers
#   built with Apple LLVM version 10.0.1 (clang-1001.0.46.4)
#   configuration: --prefix=/usr/local/Cellar/ffmpeg/4.1.4_2 --enable-shared --enable-pthreads --enable-version3 --enable-avresample --cc=clang --host-cflags='-I/Library/Java/JavaVirtualMachines/adoptopenjdk-12.0.1.jdk/Contents/Home/include -I/Library/Java/JavaVirtualMachines/adoptopenjdk-12.0.1.jdk/Contents/Home/include/darwin' --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libbluray --enable-libmp3lame --enable-libopus --enable-librubberband --enable-libsnappy --enable-libtesseract --enable-libtheora --enable-libvorbis --enable-libvpx --enable-libx264 --enable-libx265 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-librtmp --enable-libspeex --enable-videotoolbox --disable-libjack --disable-indev=jack --enable-libaom --enable-libsoxr
#   libavutil      56. 22.100 / 56. 22.100
#   libavcodec     58. 35.100 / 58. 35.100
#   libavformat    58. 20.100 / 58. 20.100
#   libavdevice    58.  5.100 / 58.  5.100
#   libavfilter     7. 40.101 /  7. 40.101
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  3.100 /  5.  3.100
#   libswresample   3.  3.100 /  3.  3.100
#   libpostproc    55.  3.100 / 55.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'metropolis.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.45.100
#   Duration: 02:28:54.25, start: 0.000000, bitrate: 1622 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1920x1080 [SAR 1:1 DAR 16:9], 1488 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 47.95 tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
# Output #0, mp4, to 'metropolis/metropolis_section10.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.20.100
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 1488 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 24k tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# 4467.0459165 4913.75050815
# frame=10710 fps=0.0 q=-1.0 Lsize=   75143kB time=00:07:26.69 bitrate=1378.1kbits/s speed= 958x
# video:67846kB audio:6980kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.423639%
# ffmpeg version 4.1.4 Copyright (c) 2000-2019 the FFmpeg developers
#   built with Apple LLVM version 10.0.1 (clang-1001.0.46.4)
#   configuration: --prefix=/usr/local/Cellar/ffmpeg/4.1.4_2 --enable-shared --enable-pthreads --enable-version3 --enable-avresample --cc=clang --host-cflags='-I/Library/Java/JavaVirtualMachines/adoptopenjdk-12.0.1.jdk/Contents/Home/include -I/Library/Java/JavaVirtualMachines/adoptopenjdk-12.0.1.jdk/Contents/Home/include/darwin' --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libbluray --enable-libmp3lame --enable-libopus --enable-librubberband --enable-libsnappy --enable-libtesseract --enable-libtheora --enable-libvorbis --enable-libvpx --enable-libx264 --enable-libx265 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-librtmp --enable-libspeex --enable-videotoolbox --disable-libjack --disable-indev=jack --enable-libaom --enable-libsoxr
#   libavutil      56. 22.100 / 56. 22.100
#   libavcodec     58. 35.100 / 58. 35.100
#   libavformat    58. 20.100 / 58. 20.100
#   libavdevice    58.  5.100 / 58.  5.100
#   libavfilter     7. 40.101 /  7. 40.101
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  3.100 /  5.  3.100
#   libswresample   3.  3.100 /  3.  3.100
#   libpostproc    55.  3.100 / 55.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'metropolis.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.45.100
#   Duration: 02:28:54.25, start: 0.000000, bitrate: 1622 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1920x1080 [SAR 1:1 DAR 16:9], 1488 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 47.95 tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
# Output #0, mp4, to 'metropolis/metropolis_section11.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.20.100
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 1488 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 24k tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# 4913.75050815 5360.4550998
# frame=10698 fps=0.0 q=-1.0 Lsize=   70765kB time=00:07:26.69 bitrate=1297.8kbits/s speed= 871x
# video:63468kB audio:6980kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.449725%
# ffmpeg version 4.1.4 Copyright (c) 2000-2019 the FFmpeg developers
#   built with Apple LLVM version 10.0.1 (clang-1001.0.46.4)
#   configuration: --prefix=/usr/local/Cellar/ffmpeg/4.1.4_2 --enable-shared --enable-pthreads --enable-version3 --enable-avresample --cc=clang --host-cflags='-I/Library/Java/JavaVirtualMachines/adoptopenjdk-12.0.1.jdk/Contents/Home/include -I/Library/Java/JavaVirtualMachines/adoptopenjdk-12.0.1.jdk/Contents/Home/include/darwin' --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libbluray --enable-libmp3lame --enable-libopus --enable-librubberband --enable-libsnappy --enable-libtesseract --enable-libtheora --enable-libvorbis --enable-libvpx --enable-libx264 --enable-libx265 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-librtmp --enable-libspeex --enable-videotoolbox --disable-libjack --disable-indev=jack --enable-libaom --enable-libsoxr
#   libavutil      56. 22.100 / 56. 22.100
#   libavcodec     58. 35.100 / 58. 35.100
#   libavformat    58. 20.100 / 58. 20.100
#   libavdevice    58.  5.100 / 58.  5.100
#   libavfilter     7. 40.101 /  7. 40.101
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  3.100 /  5.  3.100
#   libswresample   3.  3.100 /  3.  3.100
#   libpostproc    55.  3.100 / 55.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'metropolis.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.45.100
#   Duration: 02:28:54.25, start: 0.000000, bitrate: 1622 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1920x1080 [SAR 1:1 DAR 16:9], 1488 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 47.95 tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
# Output #0, mp4, to 'metropolis/metropolis_section12.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.20.100
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 1488 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 24k tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# 5360.4550998 5807.1596914500005
# frame=10678 fps=0.0 q=-1.0 Lsize=   59895kB time=00:07:26.69 bitrate=1098.4kbits/s speed= 846x
# video:52600kB audio:6980kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.529709%
# ffmpeg version 4.1.4 Copyright (c) 2000-2019 the FFmpeg developers
#   built with Apple LLVM version 10.0.1 (clang-1001.0.46.4)
#   configuration: --prefix=/usr/local/Cellar/ffmpeg/4.1.4_2 --enable-shared --enable-pthreads --enable-version3 --enable-avresample --cc=clang --host-cflags='-I/Library/Java/JavaVirtualMachines/adoptopenjdk-12.0.1.jdk/Contents/Home/include -I/Library/Java/JavaVirtualMachines/adoptopenjdk-12.0.1.jdk/Contents/Home/include/darwin' --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libbluray --enable-libmp3lame --enable-libopus --enable-librubberband --enable-libsnappy --enable-libtesseract --enable-libtheora --enable-libvorbis --enable-libvpx --enable-libx264 --enable-libx265 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-librtmp --enable-libspeex --enable-videotoolbox --disable-libjack --disable-indev=jack --enable-libaom --enable-libsoxr
#   libavutil      56. 22.100 / 56. 22.100
#   libavcodec     58. 35.100 / 58. 35.100
#   libavformat    58. 20.100 / 58. 20.100
#   libavdevice    58.  5.100 / 58.  5.100
#   libavfilter     7. 40.101 /  7. 40.101
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  3.100 /  5.  3.100
#   libswresample   3.  3.100 /  3.  3.100
#   libpostproc    55.  3.100 / 55.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'metropolis.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.45.100
#   Duration: 02:28:54.25, start: 0.000000, bitrate: 1622 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1920x1080 [SAR 1:1 DAR 16:9], 1488 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 47.95 tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
# Output #0, mp4, to 'metropolis/metropolis_section13.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.20.100
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 1488 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 24k tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# 5807.1596914500005 6253.864283100001
# frame=10664 fps=0.0 q=-1.0 Lsize=   62728kB time=00:07:26.69 bitrate=1150.4kbits/s speed= 770x
# video:55433kB audio:6980kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.505035%
# ffmpeg version 4.1.4 Copyright (c) 2000-2019 the FFmpeg developers
#   built with Apple LLVM version 10.0.1 (clang-1001.0.46.4)
#   configuration: --prefix=/usr/local/Cellar/ffmpeg/4.1.4_2 --enable-shared --enable-pthreads --enable-version3 --enable-avresample --cc=clang --host-cflags='-I/Library/Java/JavaVirtualMachines/adoptopenjdk-12.0.1.jdk/Contents/Home/include -I/Library/Java/JavaVirtualMachines/adoptopenjdk-12.0.1.jdk/Contents/Home/include/darwin' --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libbluray --enable-libmp3lame --enable-libopus --enable-librubberband --enable-libsnappy --enable-libtesseract --enable-libtheora --enable-libvorbis --enable-libvpx --enable-libx264 --enable-libx265 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-librtmp --enable-libspeex --enable-videotoolbox --disable-libjack --disable-indev=jack --enable-libaom --enable-libsoxr
#   libavutil      56. 22.100 / 56. 22.100
#   libavcodec     58. 35.100 / 58. 35.100
#   libavformat    58. 20.100 / 58. 20.100
#   libavdevice    58.  5.100 / 58.  5.100
#   libavfilter     7. 40.101 /  7. 40.101
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  3.100 /  5.  3.100
#   libswresample   3.  3.100 /  3.  3.100
#   libpostproc    55.  3.100 / 55.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'metropolis.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.45.100
#   Duration: 02:28:54.25, start: 0.000000, bitrate: 1622 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1920x1080 [SAR 1:1 DAR 16:9], 1488 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 47.95 tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
# Output #0, mp4, to 'metropolis/metropolis_section14.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.20.100
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 1488 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 24k tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# 6253.864283100001 6700.568874750001
# frame=10686 fps=0.0 q=-1.0 Lsize=   99223kB time=00:07:26.69 bitrate=1819.7kbits/s speed= 722x
# video:91925kB audio:6980kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.322112%
# ffmpeg version 4.1.4 Copyright (c) 2000-2019 the FFmpeg developers
#   built with Apple LLVM version 10.0.1 (clang-1001.0.46.4)
#   configuration: --prefix=/usr/local/Cellar/ffmpeg/4.1.4_2 --enable-shared --enable-pthreads --enable-version3 --enable-avresample --cc=clang --host-cflags='-I/Library/Java/JavaVirtualMachines/adoptopenjdk-12.0.1.jdk/Contents/Home/include -I/Library/Java/JavaVirtualMachines/adoptopenjdk-12.0.1.jdk/Contents/Home/include/darwin' --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libbluray --enable-libmp3lame --enable-libopus --enable-librubberband --enable-libsnappy --enable-libtesseract --enable-libtheora --enable-libvorbis --enable-libvpx --enable-libx264 --enable-libx265 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-librtmp --enable-libspeex --enable-videotoolbox --disable-libjack --disable-indev=jack --enable-libaom --enable-libsoxr
#   libavutil      56. 22.100 / 56. 22.100
#   libavcodec     58. 35.100 / 58. 35.100
#   libavformat    58. 20.100 / 58. 20.100
#   libavdevice    58.  5.100 / 58.  5.100
#   libavfilter     7. 40.101 /  7. 40.101
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  3.100 /  5.  3.100
#   libswresample   3.  3.100 /  3.  3.100
#   libpostproc    55.  3.100 / 55.  3.100
# 6700.568874750001 7147.273466400001
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'metropolis.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.45.100
#   Duration: 02:28:54.25, start: 0.000000, bitrate: 1622 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1920x1080 [SAR 1:1 DAR 16:9], 1488 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 47.95 tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
# Output #0, mp4, to 'metropolis/metropolis_section15.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.20.100
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 1488 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 24k tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# frame=10642 fps=0.0 q=-1.0 Lsize=  130223kB time=00:07:26.69 bitrate=2388.2kbits/s speed= 642x
# video:122925kB audio:6980kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.245043%
# 7147.273466400001 7593.978058050001
# ffmpeg version 4.1.4 Copyright (c) 2000-2019 the FFmpeg developers
#   built with Apple LLVM version 10.0.1 (clang-1001.0.46.4)
#   configuration: --prefix=/usr/local/Cellar/ffmpeg/4.1.4_2 --enable-shared --enable-pthreads --enable-version3 --enable-avresample --cc=clang --host-cflags='-I/Library/Java/JavaVirtualMachines/adoptopenjdk-12.0.1.jdk/Contents/Home/include -I/Library/Java/JavaVirtualMachines/adoptopenjdk-12.0.1.jdk/Contents/Home/include/darwin' --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libbluray --enable-libmp3lame --enable-libopus --enable-librubberband --enable-libsnappy --enable-libtesseract --enable-libtheora --enable-libvorbis --enable-libvpx --enable-libx264 --enable-libx265 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-librtmp --enable-libspeex --enable-videotoolbox --disable-libjack --disable-indev=jack --enable-libaom --enable-libsoxr
#   libavutil      56. 22.100 / 56. 22.100
#   libavcodec     58. 35.100 / 58. 35.100
#   libavformat    58. 20.100 / 58. 20.100
#   libavdevice    58.  5.100 / 58.  5.100
#   libavfilter     7. 40.101 /  7. 40.101
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  3.100 /  5.  3.100
#   libswresample   3.  3.100 /  3.  3.100
#   libpostproc    55.  3.100 / 55.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'metropolis.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.45.100
#   Duration: 02:28:54.25, start: 0.000000, bitrate: 1622 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1920x1080 [SAR 1:1 DAR 16:9], 1488 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 47.95 tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
# Output #0, mp4, to 'metropolis/metropolis_section16.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.20.100
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 1488 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 24k tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# frame=10667 fps=0.0 q=-1.0 Lsize=  165891kB time=00:07:26.69 bitrate=3042.3kbits/s speed= 561x
# video:158591kB audio:6980kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.193512%
# ffmpeg version 4.1.4 Copyright (c) 2000-2019 the FFmpeg developers
#   built with Apple LLVM version 10.0.1 (clang-1001.0.46.4)
#   configuration: --prefix=/usr/local/Cellar/ffmpeg/4.1.4_2 --enable-shared --enable-pthreads --enable-version3 --enable-avresample --cc=clang --host-cflags='-I/Library/Java/JavaVirtualMachines/adoptopenjdk-12.0.1.jdk/Contents/Home/include -I/Library/Java/JavaVirtualMachines/adoptopenjdk-12.0.1.jdk/Contents/Home/include/darwin' --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libbluray --enable-libmp3lame --enable-libopus --enable-librubberband --enable-libsnappy --enable-libtesseract --enable-libtheora --enable-libvorbis --enable-libvpx --enable-libx264 --enable-libx265 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-librtmp --enable-libspeex --enable-videotoolbox --disable-libjack --disable-indev=jack --enable-libaom --enable-libsoxr
#   libavutil      56. 22.100 / 56. 22.100
#   libavcodec     58. 35.100 / 58. 35.100
#   libavformat    58. 20.100 / 58. 20.100
#   libavdevice    58.  5.100 / 58.  5.100
#   libavfilter     7. 40.101 /  7. 40.101
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  3.100 /  5.  3.100
#   libswresample   3.  3.100 /  3.  3.100
#   libpostproc    55.  3.100 / 55.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'metropolis.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.45.100
#   Duration: 02:28:54.25, start: 0.000000, bitrate: 1622 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1920x1080 [SAR 1:1 DAR 16:9], 1488 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 47.95 tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
# 7593.978058050001 8040.682649700001
# Output #0, mp4, to 'metropolis/metropolis_section17.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.20.100
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 1488 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 24k tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# frame=10689 fps=0.0 q=-1.0 Lsize=  116525kB time=00:07:26.69 bitrate=2137.0kbits/s speed= 569x
# video:109227kB audio:6980kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.273837%
# ffmpeg version 4.1.4 Copyright (c) 2000-2019 the FFmpeg developers
#   built with Apple LLVM version 10.0.1 (clang-1001.0.46.4)
#   configuration: --prefix=/usr/local/Cellar/ffmpeg/4.1.4_2 --enable-shared --enable-pthreads --enable-version3 --enable-avresample --cc=clang --host-cflags='-I/Library/Java/JavaVirtualMachines/adoptopenjdk-12.0.1.jdk/Contents/Home/include -I/Library/Java/JavaVirtualMachines/adoptopenjdk-12.0.1.jdk/Contents/Home/include/darwin' --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libbluray --enable-libmp3lame --enable-libopus --enable-librubberband --enable-libsnappy --enable-libtesseract --enable-libtheora --enable-libvorbis --enable-libvpx --enable-libx264 --enable-libx265 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-librtmp --enable-libspeex --enable-videotoolbox --disable-libjack --disable-indev=jack --enable-libaom --enable-libsoxr
#   libavutil      56. 22.100 / 56. 22.100
#   libavcodec     58. 35.100 / 58. 35.100
#   libavformat    58. 20.100 / 58. 20.100
#   libavdevice    58.  5.100 / 58.  5.100
#   libavfilter     7. 40.101 /  7. 40.101
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  3.100 /  5.  3.100
#   libswresample   3.  3.100 /  3.  3.100
#   libpostproc    55.  3.100 / 55.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'metropolis.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.45.100
#   Duration: 02:28:54.25, start: 0.000000, bitrate: 1622 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1920x1080 [SAR 1:1 DAR 16:9], 1488 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 47.95 tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
# Output #0, mp4, to 'metropolis/metropolis_section18.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.20.100
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 1488 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 24k tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# 8040.682649700001 8487.387241350001
# frame=10695 fps=0.0 q=-1.0 Lsize=  163238kB time=00:07:26.69 bitrate=2993.6kbits/s speed= 532x
# video:155936kB audio:6980kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.197627%
# ffmpeg version 4.1.4 Copyright (c) 2000-2019 the FFmpeg developers
#   built with Apple LLVM version 10.0.1 (clang-1001.0.46.4)
#   configuration: --prefix=/usr/local/Cellar/ffmpeg/4.1.4_2 --enable-shared --enable-pthreads --enable-version3 --enable-avresample --cc=clang --host-cflags='-I/Library/Java/JavaVirtualMachines/adoptopenjdk-12.0.1.jdk/Contents/Home/include -I/Library/Java/JavaVirtualMachines/adoptopenjdk-12.0.1.jdk/Contents/Home/include/darwin' --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libbluray --enable-libmp3lame --enable-libopus --enable-librubberband --enable-libsnappy --enable-libtesseract --enable-libtheora --enable-libvorbis --enable-libvpx --enable-libx264 --enable-libx265 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-librtmp --enable-libspeex --enable-videotoolbox --disable-libjack --disable-indev=jack --enable-libaom --enable-libsoxr
#   libavutil      56. 22.100 / 56. 22.100
#   libavcodec     58. 35.100 / 58. 35.100
#   libavformat    58. 20.100 / 58. 20.100
#   libavdevice    58.  5.100 / 58.  5.100
#   libavfilter     7. 40.101 /  7. 40.101
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  3.100 /  5.  3.100
#   libswresample   3.  3.100 /  3.  3.100
#   libpostproc    55.  3.100 / 55.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'metropolis.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.45.100
#   Duration: 02:28:54.25, start: 0.000000, bitrate: 1622 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1920x1080 [SAR 1:1 DAR 16:9], 1488 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 47.95 tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
# Output #0, mp4, to 'metropolis/metropolis_section19.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.20.100
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p(tv, bt709), 1920x1080 [SAR 1:1 DAR 16:9], q=2-31, 1488 kb/s, 23.98 fps, 23.98 tbr, 24k tbn, 24k tbc (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#     Stream #0:1(und): Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 127 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
# Stream mapping:
#   Stream #0:0 -> #0:0 (copy)
#   Stream #0:1 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# 8487.387241350001 8934.091833
# frame=    0 fps=0.0 q=-1.0 size=       0kB time=00:00:00.00 bitrate=N/A speed=   0x
# frame=10700 fps=0.0 q=-1.0 Lsize=   63893kB time=00:07:26.69 bitrate=1171.7kbits/s speed= 553x
# video:56598kB audio:6980kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.494984%
